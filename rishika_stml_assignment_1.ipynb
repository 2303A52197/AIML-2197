# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52197/AIML-2197/blob/main/rishika_stml_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
X=[2.3,2.5,3.6,2.8,3.1,2.9,3.2,2.7,2.8,3.0]
plt.hist(X,bins=5,density=True,edgecolor='black')
plt.title('Histogram of X')
plt.xlabel('X')
plt.ylabel('Density')
plt.show()
